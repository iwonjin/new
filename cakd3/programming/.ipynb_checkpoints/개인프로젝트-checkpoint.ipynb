# %%
# gui 적용을 위해 tkinter공부중
class ChurchManagement(): # 교회관리 프로그램,  ## 최상위 클래스
    
    def __init__(self):
    
        print (" ") # 영상예배 주소
        print(' ') # 공지사항
    
    def member_manage(self): # 멤버관리 시작
        pass
    
    def car_mnage(self): # 차량관리 시작
        pass
    
    def stock(self): # 비품관리 시작
        pass
    
    
##################################
#==============================##
#==============================##
#==============================##
##################################

class MenberManagement(ChurchManagement()): # 멤버관리 클래스
    
    def look_information(self): # 성도가 데이터를 조회
        pass
    
    def change_information(self): # 관리자가 데이터를 수정
        pass
    
#################################################################

class LookInfo(MenberManagement()): # 성도 데이터 조회관련 클래스
    pass

    
class ChangeInfo(MenberManagement()): # 관리자 성도자료 수정 클래스
    # 시작하면 파일을 불러옴
    # 리스트에 저장
     def __init__(self):
            pass

            #  차량인식  메소드
    def car_confirm(self):
        pass # cctv -> 번호판 이미지 인식,  성도 차량에  일치하는 값이 있으면, 성도차량 로그에 저장하고, 차단바 올리는 신호 발생

    
    # 새로운 성도 추가
    def set_member(self):
        pass
    
    # 기존 성도정보 조회 / 변경
    def mod_member(self):
        pass
    
    #성도 정보 삭제
    def del_member(self):
        pass
    
    
##################################
#==============================##
#==============================##
#==============================##
##################################
class CarManagement(ChurchManagement()): # 차량관리시스템 클래스
    pass




###################################
#==============================##
#==============================##
#==============================##
##################################

class StockManagement(ChurchManagement()): #재고관리 시스템 클래스
    
    def look_stock(self): # 비품 정보 조회
        pass
        # 비품별
        # 장소별

    def choange_stock(self): # 비품 정보 변경
        pass
        
##########################################################

        
        

###################################
#==============================##
#==============================##
#==============================##
##################################

# %%
import tkinter as tk

## 버튼생성##


class Application(tk.Frame):
    def __init__(self, master=None):
        super().__init__(master)
        self.master = master
        self.pack()
        self.create_widgets()

    def create_widgets(self):
        self.hi_there = tk.Button(self)  ## 버튼 생성
        self.hi_there["text"] = "Hello World\n(click me)" # 표시할 텍스트
        self.hi_there["command"] = self.say_hi # 누를때 실행할 함수
        self.hi_there.pack(side="top") # 정렬?

        
        # 버튼생성2
        self.quit = tk.Button(self, text="QUIT", fg="red",  
                              command=self.master.destroy)
        self.quit.pack(side="bottom")

    def say_hi(self):
        print("hi there, everyone!")

root = tk.Tk()
app = Application(master=root)
app.mainloop()
# Out:
# hi there, everyone!
# hi there, everyone!

# %%
import tkinter as tk
## 변수값 받기 ##


class App(tk.Frame):
    def __init__(self, master):
        super().__init__(master)
        self.pack()

        self.entrythingy = tk.Entry()
        self.entrythingy.pack()

        # Create the application variable.
        self.contents = tk.StringVar()
        # Set it to some value.
        self.contents.set("this is a variable")
        # Tell the entry widget to watch this variable.
        self.entrythingy["textvariable"] = self.contents

        # Define  a callback   for when the user hits return.
        # It prints the current value of the variable.
        self.entrythingy.bind('<Key-Return>',
                             self.print_contents)

    def print_contents(self, event):
        print("Hi. The current entry content is:",
              self.contents.get())
        return  self.contents.get()

root = tk.Tk()
myapp = App(root)
myapp.mainloop()
# Out:
# Hi. The current entry content is: eeeeeeee
# Hi. The current entry content is: eeeeeeeer
