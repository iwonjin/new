# %%
# Q. 원하는 웹 사이트를 requests 모듈과 urllib 모듈로 가져와서 text로 출력하세요.

# Q. 특정 단어를 출력하세요.

# Q. 웹에서 이미지를 다운 받아 저장하세요.(가능한 이미지 선택)

# 도전 과제
# Q. 네이버 영화 랭킹 가져와서 첫번째 영화제목을 출력하세요.

# 도전 과제
# Q. 네이버 영화 랭킹 가져와서 전체 영화제목을 출력하세요.

# %%
# Out:
# ('https', 'docs.python.org', '/ko/3.9/library/re.html', '', '', '')

# %%
# Q. 원하는 웹 사이트를 requests 모듈과 urllib 모듈로 가져와서 text로 출력하세요.

# %%
import urllib
URL = 'https://docs.python.org/ko/3.9/library/re.html'
response = urllib.request.urlopen(URL)
response.read(500)
# Out:
# b'\n<!DOCTYPE html>\n\n<html xmlns="http://www.w3.org/1999/xhtml" lang="ko">\n  <head>\n    <meta charset="utf-8" />\n    <title>re \xe2\x80\x94 \xec\xa0\x95\xea\xb7\x9c\xec\x8b\x9d \xec\x97\xb0\xec\x82\xb0 &#8212; Python 3.9.6 \xeb\xac\xb8\xec\x84\x9c</title>\n    <link rel="stylesheet" href="../_static/pydoctheme.css" type="text/css" />\n    <link rel="stylesheet" href="../_static/pygments.css" type="text/css" />\n    \n    <script id="documentation_options" data-url_root="../" src="../_static/documentation_options.js"></script>\n    <script src="../_static/jquery.js"></script'

# %%
import requests
URL = 'https://docs.python.org/ko/3.9/library/re.html'
respon = requests.get(URL)
respon.text[:2000]
R = respon.encode('UTF-8')
R
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-114-22139503fbce> in <module>
#       3 respon = requests.get(URL)
#       4 respon.text[:2000]
# ----> 5 R = respon.encode('UTF-8')
#       6 R
#
# AttributeError: 'Response' object has no attribute 'encode'

# %%
  #-*- coding: utf-8 -*-
  test_utf8 = 'rocksea 블로그'
  test_euckr = unicode(test_utf8,'utf-8').encode('euc-kr')
  print test_utf8
  print test_euckr
  print unicode(test_euckr,'euc-kr').encode('unicode-escape')
  print unicode(test_euckr,'euc-kr')

# %%
# Q. 특정 단어를 출력하세요.
# body = re.sub('<.+?>','',body)

# %%
import urllib
import re
URL = 'https://dandyrilla.github.io/2017-08-12/pandas-10min/#5-%EC%97%B0%EC%82%B0-operations'
response = urllib.request.urlopen(URL)


test_utf8 = response
re.UNICODE()
test_euckr = unicode(test_utf8,'utf-8').encode('utf-8')
print test_utf8
print test_euckr
print unicode(test_euckr,'euc-kr').encode('unicode-escape')
print unicode(test_euckr,'euc-kr')


#text = str( response.read() )
text =  response.read() 
print( type(text) )
#re.findall('[가-힣]+[ 가-힣a-zA-Z0-9]*',text )
R = re.search('[가-힣]+[ 가-힣a-zA-Z0-9]*',text )
print(R)
# Out:
#   File "<ipython-input-38-990966d44de5>", line 9
#     print test_utf8
#           ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(test_utf8)?

# %%
import requests
URL = 'https://news.naver.com/main/opinion/home.nhn'
headers = {"User-Agent": 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.77 Safari/537.36' }
response = requests.get(URL,headers=headers )
#response.text[:]

# %%
import requests
URL = 'https://news.naver.com/main/opinion/home.nhn'
headers = {"User-Agent": 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.77 Safari/537.36' }
response = requests.get(URL,headers=headers )
text = response.text
R = re.findall('[가-힣]+[ 가-힣a-zA-Z0-9]*',text )
R[10:20]
# Out:
# ['네이버 뉴스', '네이버 뉴스', '네이버 뉴스', '정치', '경제', '사회', '생활', '문화', '세계', '과학 등 언론사별']

# %%
# Q. 웹에서 이미지를 다운 받아 저장하세요.(가능한 이미지 선택)
# urllib.request.urlretrieve():웹상의 이미지 저장
import urllib.request
img_src = 'https://homepages.cae.wisc.edu/~ece533/images/tulips.png'
new_name = 'img.png'
urllib.request.urlretrieve(img_src,new_name)

# %%
import requests
from bs4 import BeautifulSoup
import time

url = 'https://www.10000recipe.com/ranking/home_new.html?rtype=r&dtype=d'
headers = {"User-Agent": 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.77 Safari/537.36' }

response = requests.get(url ,headers=headers )

if response.status_code == 200:
    html = response.text
    soup = BeautifulSoup(html, 'html.parser')
    #print(soup)
    
    ul = soup.select_one('ul.common_sp_list_ul')
    #print(ul)
    titles = ul.select('li > div > a')
    i=0
    for title in titles:
        print(title.select('img')[0]['src'] )
        print()
        #print(title.select_one('a > img')['src'])
        i += 1
        if i > 10:
            i = 10
        #time.sleep(0.1)
else : 
    print(response.status_code)
# Out:
# ['<img src="https://mimgnews.pstatic.net/image/upload/office_logo/029/2018/07/18/logo_029_39_20180718140118.jpg"', '<img src="https://mimgnews.pstatic.net/image/upload/office_logo/029/2018/07/18/logo_029_39_20180718140118.jpg"', '<img src="https://mimgnews.pstatic.net/image/upload/office_logo/014/2020/09/24/logo_014_39_20200924144823.jpg"', '<img src="https://mimgnews.pstatic.net/image/upload/office_logo/014/2020/09/24/logo_014_39_20200924144823.jpg"', '<img src="https://mimgnews.pstatic.net/image/upload/office_logo/052/2020/09/18/logo_052_56_20200918202451.jpg"', '<img src="https://mimgnews.pstatic.net/image/upload/office_logo/020/2020/09/17/logo_020_56_20200917112548.jpg"', '<img src="https://mimgnews.pstatic.net/image/upload/office_logo/016/2020/11/03/logo_016_56_20201103113832.jpg"', '<img src="https://mimgnews.pstatic.net/image/upload/office_logo/011/2020/02/28/logo_011_56_20200228095228.jpg"', '<img src="https://mimgnews.pstatic.net/image/upload/office_logo/055/2020/10/07/logo_
# ...
